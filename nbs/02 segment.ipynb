# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import fastexp.blocks_segment as b

# %%
d1 = b.l1()

# %%
block, d2 = b.l2()

# %%
dset, d3 = b.l3()

# %%
d1
# Out:
# after_item:
# 	Pipeline: AddMaskCodes -> ToTensor
# before_batch:
# 	 Pipeline:
# after_batch:
# 	 Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}

# %%
d2
# Out:
# after_item:
# 	Pipeline: AddMaskCodes -> ToTensor
# before_batch:
# 	 Pipeline:
# after_batch:
# 	 Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}

# %%
d3
# Out:
# after_item:
# 	Pipeline: AddMaskCodes -> ToTensor
# before_batch:
# 	 Pipeline:
# after_batch:
# 	 Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}

# %%
d1.one_batch()
# Out:
# (TensorImage([[[[0.3373, 0.5569, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#            [0.7255, 0.3686, 0.6196,  ..., 1.0000, 1.0000, 1.0000],
#            [0.8941, 0.7137, 0.3529,  ..., 1.0000, 1.0000, 1.0000],
#            ...,
#            [0.2902, 0.2941, 0.3137,  ..., 0.4235, 0.4549, 0.4784],
#            [0.2902, 0.2980, 0.3020,  ..., 0.3922, 0.4471, 0.4314],
#            [0.2824, 0.2784, 0.2941,  ..., 0.3804, 0.4118, 0.4157]],
#
#           [[0.3255, 0.5529, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#            [0.7216, 0.3529, 0.6118,  ..., 1.0000, 1.0000, 1.0000],
#            [0.8941, 0.7098, 0.3412,  ..., 1.0000, 1.0000, 1.0000],
#            ...,
#            [0.2902, 0.2941, 0.3137,  ..., 0.4392, 0.4667, 0.4902],
#            [0.2902, 0.2941, 0.2980,  ..., 0.4039, 0.4627, 0.4431],
#            [0.2824, 0.2784, 0.2941,  ..., 0.3922, 0.4235, 0.4275]],
#
#           [[0.3098, 0.4667, 0.9804,  ..., 1.0000, 1.0000, 1.0000],
# ...

# %%
from collections.abc import *

# %%
isinstance(d1.train, Iterator)
# Out:
# False

# %%
type(d1.train).mro()
# Out:
# [fastai.data.core.TfmdDL,
#  fastai.data.load.DataLoader,
#  fastcore.basics.GetAttr,
#  object]

# %%
d1.show_batch()

# %%
d3.show_batch()

# %%
d2.show_batch()
